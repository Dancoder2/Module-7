# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\danol\appdata\local\programs\python\python314\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\danol\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\danol\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\danol\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\danol\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\danol\appdata\local\programs\python\python314\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# %% [markdown]
#  ### 1. Create

# %% [markdown]
# **1.1 Create from a CSV**

# %%
df = pd.read_csv('Dan.csv')

# %% [markdown]
# 1.2 Create from a Dictionary

# %%
tempdict = {' col1':[1,2,3], 'col2':[4,5,6],'col3':[7,8,9]}

# %%
dictdf = pd.DataFrame.from_dict(tempdict)

# %% [markdown]
# ### 2. Read

# %%
df.head(10)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
# 5    AL             118        510                Yes              No
# 6    MA             121        510                 No             Yes
# 7    MO             147        415                Yes              No
# 8    LA             117        408                 No              No
# 9    WV             141        415                Yes             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
# 5                      0              223.4             98.0
# 6                     24              218.2             88.0
# 7                      0              157.0             79.0
# 8                      0              184.5             97.0
# 9                     37              258.6             84.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# 1             27.47              195.5            103.0             16.62
# 2             41.38              121.2            110.0             10.30
# 3             50.90               61.9             88.0              5.26
# 4             28.34              148.3            122.0             12.61
# 5             37.98              220.6            101.0             18.75
# 6             37.09              348.5            108.0             29.62
# 7             26.69              103.1             94.0              8.76
# 8             31.37              351.6             80.0             29.89
# 9             43.96              222.0            111.0             18.87
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7               91.0               11.01
# 1                254.4              103.0               11.45
# 2                162.6              104.0                7.32
# 3                196.9               89.0                8.86
# 4                186.9              121.0                8.41
# 5                203.9              118.0                9.18
# 6                212.6              118.0                9.57
# 7                211.8               96.0                9.53
# 8                215.8               90.0                9.71
# 9                326.4               97.0               14.69
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
# 5                 6.3                 6               1.70
# 6                 7.5                 7               2.03
# 7                 7.1                 6               1.92
# 8                 8.7                 4               2.35
# 9                11.2                 5               3.02
#
#    Customer service calls  Churn
# 0                     1.0  False
# 1                     1.0  False
# 2                     0.0  False
# 3                     2.0  False
# 4                     3.0  False
# 5                     0.0  False
# 6                     3.0    NaN
# 7                     0.0  False
# 8                     1.0  False
# 9                     0.0  False

# %%
dictdf.head()
# Out:
#     col1  col2  col3
# 0      1     4     7
# 1      2     5     8
# 2      3     6     9

# %%
df.tail(15)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3318    OK              52        415                 No              No
# 3319    WY              89        415                 No              No
# 3320    GA             122        510                Yes              No
# 3321    VT              60        415                 No              No
# 3322    MD              62        408                 No              No
# 3323    IN             117        415                 No              No
# 3324    WV             159        415                 No              No
# 3325    OH              78        408                 No              No
# 3326    OH              96        415                 No              No
# 3327    SC              79        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3318                      0              124.9            131.0
# 3319                      0              115.4             99.0
# 3320                      0              140.0            101.0
# 3321                      0              193.9            118.0
# 3322                      0              321.1            105.0
# 3323                      0              118.4            126.0
# 3324                      0              169.8            114.0
# 3325                      0              193.4             99.0
# 3326                      0              106.6            128.0
# 3327                      0              134.7             98.0
# 3328                     36              156.2             77.0
# 3329                      0              231.1             57.0
# 3330                      0              180.8            109.0
# 3331                      0              213.8            105.0
# 3332                     25              234.4            113.0
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3318             21.23              300.5            118.0             25.54
# 3319             19.62              209.9            115.0             17.84
# 3320             23.80              196.4             77.0             16.69
# 3321             32.96               85.0            110.0              7.23
# 3322             54.59              265.5            122.0             22.57
# 3323             20.13              249.3             97.0             21.19
# 3324             28.87              197.7            105.0             16.80
# 3325             32.88              116.9             88.0              9.94
# 3326             18.12              284.8             87.0             24.21
# 3327             22.90              189.7             68.0             16.12
# 3328             26.55              215.5            126.0             18.32
# 3329             39.29              153.4             55.0             13.04
# 3330             30.74              288.8             58.0             24.55
# 3331             36.35              159.6             84.0             13.57
# 3332             39.85              265.9             82.0             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 3318                192.5              106.0                8.66
# 3319                280.9              112.0               12.64
# 3320                120.1              133.0                5.40
# 3321                210.1              134.0                9.45
# 3322                180.5               72.0                8.12
# 3323                227.0               56.0               10.22
# 3324                193.7               82.0                8.72
# 3325                243.3              109.0               10.95
# 3326                178.9               92.0                8.05
# 3327                221.4              128.0                9.96
# 3328                279.1               83.0               12.56
# 3329                191.3              123.0                8.61
# 3330                191.9               91.0                8.64
# 3331                139.2              137.0                6.26
# 3332                241.4               77.0               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 3318                11.6                 4               3.13
# 3319                15.9                 6               4.29
# 3320                 9.7                 4               2.62
# 3321                13.2                 8               3.56
# 3322                11.5                 2               3.11
# 3323                13.6                 3               3.67
# 3324                11.6                 4               3.13
# 3325                 9.3                 4               2.51
# 3326                14.9                 7               4.02
# 3327                11.8                 5               3.19
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 3318                     2.0  False
# 3319                     3.0  False
# 3320                     4.0   True
# 3321                     3.0  False
# 3322                     4.0   True
# 3323                     5.0   True
# 3324                     1.0  False
# 3325                     2.0  False
# 3326                     1.0  False
# 3327                     2.0  False
# 3328                     2.0  False
# 3329                     3.0  False
# 3330                     2.0  False
# 3331                     2.0  False
# 3332                     0.0  False

# %% [markdown]
# **2.2 Show columns and Data Type**

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls           float64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls           float64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls         float64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls    float64
# Churn                      object
# dtype: object

# %% [markdown]
# **2.3 Summary Statistics**

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3323.000000
# mean       101.064806   437.182418               8.099010         179.787150
# std         39.822106    42.371290              13.688365          54.419625
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.500000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3323.000000       3315.000000        3324.000000      3325.000000
# mean        100.456214         30.557831         201.033935       100.110677
# std          20.057356          9.255987          50.676652        19.932115
# min           0.000000          0.000000           0.000000         0.000000
# 25%          87.000000         24.420000         166.600000        87.000000
# 50%         101.000000         30.500000         201.400000       100.000000
# 75%         114.000000         36.780000         235.325000       114.000000
# max         165.000000         59.640000         363.700000       170.000000
#
#        Total eve charge  Total night minutes  Total night calls  \
# count       3333.000000          3333.000000        3332.000000
# mean          17.083540           200.872037         100.115246
# std            4.310668            50.573847          19.566710
# min            0.000000            23.200000          33.000000
# 25%           14.160000           167.000000          87.000000
# 50%           17.120000           201.200000         100.000000
# 75%           20.000000           235.300000         113.000000
# max           30.910000           395.000000         175.000000
#
#        Total night charge  Total intl minutes  Total intl calls  \
# count         3333.000000         3333.000000       3333.000000
# mean             9.039325           10.237294          4.479448
# std              2.275873            2.791840          2.461214
# min              1.040000            0.000000          0.000000
# 25%              7.520000            8.500000          3.000000
# 50%              9.050000           10.300000          4.000000
# 75%             10.590000           12.100000          6.000000
# max             17.770000           20.000000         20.000000
#
#        Total intl charge  Customer service calls
# count        3328.000000             3328.000000
# mean            2.764588                1.563101
# std             0.754086                1.315870
# min             0.000000                0.000000
# 25%             2.300000                1.000000
# 50%             2.780000                1.000000
# 75%             3.270000                2.000000
# max             5.400000                9.000000

# %%
df.describe(include = 'object')

# %% [markdown]
# **2.4 Filtering Columns**

# %%
df.State

# %%
df['International plan']

# %%
df[[ 'State','International plan']]

# %%
df.State.unique()

# %% [markdown]
# **2.5 Filtering Rows**

# %%
df.head(15)

# %%
df[df['International plan']=='No']

# %%
df[(df['International plan' ] == 'No' ) & (df['Churn' ] == False )]

# %% [markdown]
# **2.6 Indexing with iloc**

# %%
df.iloc[15]

# %%
df.iloc[15,3]

# %%
df.iloc[44:73]

# %% [markdown]
# **2.7 Indexing with loc**

# %%
state = df.copy()
state.set_index('State', inplace=True)

# %%
state.head()

# %%
state.loc['NY']

# %% [markdown]
# ### 3. Update

# %% [markdown]
# **3.1 Dropping Rows**

# %%
df.isnull().sum()

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()

# %% [markdown]
# **3.2 Dropping Columns**

# %%
df.drop('Total intl charge', axis=1)

# %% [markdown]
# **3.3 Creating Calculated Columns**

# %%
df['New Column' ] = df['Total night minutes' ] + df['Total intl minutes' ]

# %%
df.head()

# %% [markdown]
# **3.4 Updating an Entire Columns**

# %%
df['New Column' ] =100

# %%
df.head()

# %% [markdown]
# **3.5 Updating a Single Value**

# %%
df.iloc[0,-1]= 10

# %%
df.head()

# %% [markdown]
# **3.6 Condition based Updating using Apply**

# %%
df['Churn Binary'] = df['Churn' ].apply(lambda x: 1 if x == True else 0)

# %%
df.head()

# %% [markdown]
# ### 4. Delete/Output

# %% [markdown]
# **4.1 Output to CSV**

# %%
df.to_csv('Module7.csv')

# %% [markdown]
# **4.2 Output to JSON**

# %%
df.to_json()

# %% [markdown]
# **4.3 Output to HTML**

# %%
df.to_html()

# %% [markdown]
# **4.4 Delete to DataFrame**

# %%
del df
